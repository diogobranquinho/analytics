# %%
#importando as bibliotecas
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # PDT - Análise Político-Eleitoral – SJCampos

# %% [markdown]
# ## 1. Quantos eleitores tem SJCampos hoje?

# %%
qtd_eleitorado = pd.read_csv('../data/qtd_eleitor_mensal-zona_2024_1_sp_sao_jose_dos_campos.csv', low_memory=False, delimiter=';',encoding='latin-1')
qtd_eleitorado
# Out:
#    nr_ano  nr_mes sg_uf  nr_zona pc_eleitor_biometria  qt_eleitor  \
# 0    2024       1    SP      127               0,9068      135934
# 1    2024       1    SP      282               0,9022       78536
# 2    2024       1    SP      411               0,9006      139329
# 3    2024       1    SP      412               0,9015      179211
#
#    qt_eleitor_biometria             dt_carga
# 0                123260  2024-02-01 14:13:58
# 1                 70853  2024-02-01 14:13:58
# 2                125480  2024-02-01 14:13:58
# 3                161565  2024-02-01 14:13:58

# %%
dados_agrupados = qtd_eleitorado.groupby('nr_zona')['qt_eleitor'].sum().reset_index()

total_eleitores = dados_agrupados['qt_eleitor'].sum()

plt.figure(figsize=(15, 10))
ax = sns.barplot(x='nr_zona', y='qt_eleitor', data=dados_agrupados, color='blue')

for index, value in enumerate(dados_agrupados['qt_eleitor']):
    ax.text(index, value, str(value), ha='center', va='bottom')

plt.xlabel('Zona Eleitoral')
plt.ylabel('Quantidade de Eleitores')
plt.title(f'Quantidade de Eleitores por Zona Eleitoral - Total: {total_eleitores} - Ref Jan/2024')
plt.show()

# %%
perfil_eleitorado = pd.read_csv('../data/perfil_eleitor_mensal-zona_2024_1_sp_sao_jose_dos_campos.csv', low_memory=False, delimiter=';',encoding='latin-1')
perfil_eleitorado
# Out:
#      nr_ano  nr_mes ds_pais_uf nm_regiao sg_uf  nr_zona  \
# 0      2024       1     Brasil   SUDESTE    SP      127
# 1      2024       1     Brasil   SUDESTE    SP      127
# 2      2024       1     Brasil   SUDESTE    SP      411
# 3      2024       1     Brasil   SUDESTE    SP      411
# 4      2024       1     Brasil   SUDESTE    SP      412
# ..      ...     ...        ...       ...   ...      ...
# 156    2024       1     Brasil   SUDESTE    SP      412
# 157    2024       1     Brasil   SUDESTE    SP      412
# 158    2024       1     Brasil   SUDESTE    SP      282
# 159    2024       1     Brasil   SUDESTE    SP      411
# 160    2024       1     Brasil   SUDESTE    SP      412
#
#             ds_estado_civil              ds_grau_instrucao  cd_grau_instrucao  \
# 0                DIVORCIADO        ENSINO MÉDIO INCOMPLETO                  5
# 1                     VIÚVO              SUPERIOR COMPLETO                  8
# 2                    CASADO        ENSINO MÉDIO INCOMPLETO                  5
# 3                  SOLTEIRO                   LÊ E ESCREVE                  2
# 4                  SOLTEIRO        ENSINO MÉDIO INCOMPLETO                  5
# ..                      ...                            ...                ...
# 156              DIVORCIADO              SUPERIOR COMPLETO                  8
# 157                SOLTEIRO          ENSINO MÉDIO COMPLETO                  6
# 158                  CASADO        ENSINO MÉDIO INCOMPLETO                  5
# 159  SEPARADO JUDICIALMENTE  ENSINO FUNDAMENTAL INCOMPLETO                  3
# 160                   VIÚVO  ENSINO FUNDAMENTAL INCOMPLETO                  3
#
#     pc_eleitor_biometria  qt_eleitor  qt_eleitor_biometria  \
# 0                 0,9303         330                   307
# 1                  0,968         968                   937
# 2                 0,9468        3198                  3028
# 3                 0,8387         465                   390
# 4                 0,6635       13939                  9248
# ..                   ...         ...                   ...
# 156               0,9764        2961                  2891
# 157               0,8125       36270                 29469
# 158               0,9569        2226                  2130
# 159               0,9683         567                   549
# 160               0,9723        1877                  1825
#
#                 dt_carga
# 0    2024-02-01 14:13:58
# 1    2024-02-01 14:13:58
# 2    2024-02-01 14:13:58
# 3    2024-02-01 14:13:58
# 4    2024-02-01 14:13:58
# ..                   ...
# 156  2024-02-01 14:13:58
# 157  2024-02-01 14:13:58
# 158  2024-02-01 14:13:58
# 159  2024-02-01 14:13:58
# 160  2024-02-01 14:13:58
#
# [161 rows x 13 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 perfil_eleitorado = pd.read_csv('../data/perfil_eleitor_mensal-zona_2024_1_sp_sao_jose_dos_campos.csv', low_memory=False, delimiter=';',encoding='latin-1')
#       2 perfil_eleitorado
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:239, in CParserWrapper.read(self, nrows)
#     236         data = _concatenate_chunks(chunks)
#     238     else:
# --> 239         data = self._reader.read(nrows)
#     240 except StopIteration:
#     241     if self._first_chunk:
#
# KeyboardInterrupt:

# %%
dados_agrupados = perfil_eleitorado.groupby(['nr_zona', 'ds_grau_instrucao'])['qt_eleitor'].sum().reset_index()

plt.figure(figsize=(15, 10))
ax = sns.barplot(x='nr_zona', y='qt_eleitor', hue='ds_grau_instrucao', data=dados_agrupados, palette='viridis')

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.xlabel('Zona Eleitoral')
plt.ylabel('Quantidade de Eleitores')
plt.title('Quantidade de Eleitores por Zona Eleitoral e Grau de Instrução - Ref Jan/2024')
plt.legend(title='Grau de Instrução', loc='upper left')
plt.show()

# %%
dados_agrupados = perfil_eleitorado.groupby(['nr_zona', 'ds_grau_instrucao'])['qt_eleitor'].sum().reset_index()

plt.figure(figsize=(15, 10))
ax = sns.barplot(x='nr_zona', y='qt_eleitor', hue='ds_grau_instrucao', data=dados_agrupados, palette='viridis')

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.xlabel('Zona Eleitoral')
plt.ylabel('Quantidade de Eleitores')
plt.title('Quantidade de Eleitores por Zona Eleitoral e Grau de Instrução - Ref Jan/2024')
plt.legend(title='Grau de Instrução', loc='upper left')
plt.show()

# %%
dados_agrupados = perfil_eleitorado.groupby(['nr_zona', 'ds_estado_civil'])['qt_eleitor'].sum().reset_index()

plt.figure(figsize=(15, 10))
ax = sns.barplot(x='nr_zona', y='qt_eleitor', hue='ds_estado_civil', data=dados_agrupados, palette='viridis')

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.xlabel('Zona Eleitoral')
plt.ylabel('Quantidade de Eleitores')
plt.title('Quantidade de Eleitores por Zona Eleitoral e Estado Civil - Ref Jan/2024')
plt.legend(title='Estado Civil', loc='center right')
plt.show()

# %% [markdown]
# ## 2. Qual é o quociente eleitoral estimado p/ 2024 (vereadores)?

# %% [markdown]
# ### Quociente Eleitoral em 2020

# %%
quociente2020 = pd.read_csv('../data/quociente_eleitoral-municipio_2020_sp_sao_jose_dos_campos.csv', low_memory=False, delimiter=';',encoding='latin-1')
quociente2020sjc = quociente2020.loc[quociente2020['nm_municipio_tse'] == "SÃO JOSÉ DOS CAMPOS"]

votos_validos_2020 = quociente2020sjc['qt_votos_validos_qe'].iloc[0]
assentos = quociente2020sjc['qt_vagas_qe'].iloc[0]
qe_2020 = quociente2020sjc['vr_quociente_eleitoral'].iloc[0]

print(f"QE = votos_validos / num_assentos")
print(f"QE = {votos_validos_2020} / {assentos} = {qe_2020}")
# Out:
# QE = votos_validos / num_assentos
# QE = 345932 / 21 = 16473

# %%
quociente2020sjc
# Out:
#       aa_eleicao sg_uf     nm_municipio_tse  cd_cargo  nm_cargo  \
# 28          2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 53          2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 58          2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 71          2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 73          2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 114         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 118         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 131         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 148         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 167         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 200         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 238         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 282         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 348         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 367         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 376         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 514         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 530         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 913         2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 1202        2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 1360        2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 2111        2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 2759        2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
# 5415        2020    SP  SÃO JOSÉ DOS CAMPOS        13  Vereador
#
#       qt_votos_validos_qe  qt_vagas_qe  vr_quociente_eleitoral tx_legenda_tot  \
# 28                 345932           21                   16473           PSDB
# 53                 345932           21                   16473            PTB
# 58                 345932           21                   16473             PL
# 71                 345932           21                   16473            MDB
# 73                 345932           21                   16473             PT
# 114                345932           21                   16473            PSL
# 118                345932           21                   16473      CIDADANIA
# 131                345932           21                   16473            DEM
# 148                345932           21                   16473            PSD
# 167                345932           21                   16473           NOVO
# 200                345932           21                   16473   REPUBLICANOS
# 238                345932           21                   16473  SOLIDARIEDADE
# 282                345932           21                   16473            PSC
# 348                345932           21                   16473           PSOL
# 367                345932           21                   16473           PODE
# 376                345932           21                   16473           PRTB
# 514                345932           21                   16473             PP
# 530                345932           21                   16473         AVANTE
# 913                345932           21                   16473       PATRIOTA
# 1202               345932           21                   16473        PC do B
# 1360               345932           21                   16473            PTC
# 2111               345932           21                   16473           PSTU
# 2759               345932           21                   16473            PSB
# 5415               345932           21                   16473           REDE
#
#       qt_vagas_qp_preenchida  qt_vagas_media_qp  qt_vagas_qp_obtida  \
# 28                         3                  2                   3
# 53                         1                  1                   1
# 58                         1                  1                   1
# 71                         1                  1                   1
# 73                         1                  1                   1
# 114                        1                  0                   1
# 118                        1                  0                   1
# 131                        1                  0                   1
# 148                        1                  0                   1
# 167                        0                  1                   0
# 200                        0                  1                   0
# 238                        0                  1                   0
# 282                        0                  1                   0
# 348                        0                  0                   0
# 367                        0                  0                   0
# 376                        0                  0                   0
# 514                        0                  0                   0
# 530                        0                  0                   0
# 913                        0                  0                   0
# 1202                       0                  0                   0
# 1360                       0                  0                   0
# 2111                       0                  0                   0
# 2759                       0                  0                   0
# 5415                       0                  0                   0
#
#       qt_votos_coligacao_qp
# 28                    54132
# 53                    29112
# 58                    27793
# 71                    24492
# 73                    24391
# 114                   19681
# 118                   19455
# 131                   17948
# 148                   16774
# 167                   15812
# 200                   14312
# 238                   12678
# 282                   11671
# 348                   10042
# 367                    9684
# 376                    9459
# 514                    7358
# 530                    7200
# 913                    4365
# 1202                   3337
# 1360                   2917
# 2111                   1798
# 2759                   1284
# 5415                    237

# %%
dados_agrupados = quociente2020sjc.groupby('tx_legenda_tot')['qt_votos_coligacao_qp'].sum().reset_index()

total_votos_validos = dados_agrupados['qt_votos_coligacao_qp'].sum()

plt.figure(figsize=(15, 10))
ax = sns.barplot(x='tx_legenda_tot', y='qt_votos_coligacao_qp', data=dados_agrupados, color='blue')

for index, value in enumerate(dados_agrupados['qt_votos_coligacao_qp']):
    ax.text(index, value, str(value), ha='center', va='bottom')

plt.xlabel('Partidos')
plt.ylabel('Quantidade de Votos Válidos')
plt.title(f'Quantidade de Votos por Partido - Total de Votos Válidos: {total_votos_validos} - Ref Eleições 2020')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### Estimativa para 2024, utilizando a quantidade de votos válidos para presidente em 2022

# %%
presidente2022 = pd.read_csv('../data/votacao_candidato-zona_2022_sp_sao_jose_dos_campos.csv', low_memory=False, delimiter=';',encoding='latin-1')
dados_agrupados = presidente2022.groupby(['nr_zona', 'nm_candidato'])['qt_votos_nom_validos'].sum().reset_index()
total_votos_validos_2022_sjc = dados_agrupados['qt_votos_nom_validos'].sum()

print(f"QE = votos_validos / num_assentos")
print(f"QE = {total_votos_validos_2022_sjc} / 21 = {total_votos_validos_2022_sjc / 21}")
# Out:
# QE = votos_validos / num_assentos
# QE = 427611 / 21 = 20362.428571428572

# %% [markdown]
# ## Espectro de votação p/ Presidente

# %%
presidente2022
# Out:
#   sg_uf  nr_zona  cd_cargo    ds_cargo  nr_candidato  \
# 0    SP      127         1  Presidente            22
# 1    SP      127         1  Presidente            13
# 2    SP      282         1  Presidente            22
# 3    SP      282         1  Presidente            13
# 4    SP      411         1  Presidente            22
# 5    SP      411         1  Presidente            13
# 6    SP      412         1  Presidente            22
# 7    SP      412         1  Presidente            13
#
#                 nm_candidato nm_urna_candidato sg_partido  \
# 0     JAIR MESSIAS BOLSONARO    JAIR BOLSONARO         PL
# 1  LUIZ INÁCIO LULA DA SILVA              LULA         PT
# 2     JAIR MESSIAS BOLSONARO    JAIR BOLSONARO         PL
# 3  LUIZ INÁCIO LULA DA SILVA              LULA         PT
# 4     JAIR MESSIAS BOLSONARO    JAIR BOLSONARO         PL
# 5  LUIZ INÁCIO LULA DA SILVA              LULA         PT
# 6     JAIR MESSIAS BOLSONARO    JAIR BOLSONARO         PL
# 7  LUIZ INÁCIO LULA DA SILVA              LULA         PT
#
#                              ds_composicao_coligacao  nr_turno  \
# 0                             PP / REPUBLICANOS / PL         2
# 1  (PT/PC do B/PV) / SOLIDARIEDADE / (PSOL/REDE) ...         2
# 2                             PP / REPUBLICANOS / PL         2
# 3  (PT/PC do B/PV) / SOLIDARIEDADE / (PSOL/REDE) ...         2
# 4                             PP / REPUBLICANOS / PL         2
# 5  (PT/PC do B/PV) / SOLIDARIEDADE / (PSOL/REDE) ...         2
# 6                             PP / REPUBLICANOS / PL         2
# 7  (PT/PC do B/PV) / SOLIDARIEDADE / (PSOL/REDE) ...         2
#
#   ds_sit_totalizacao   dt_ult_totalizacao sg_ue  sq_candidato  \
# 0         Não Eleito  2022-10-31 00:28:52    BR  280001618036
# 1             Eleito  2022-10-31 00:28:52    BR  280001607829
# 2         Não Eleito  2022-10-31 00:28:52    BR  280001618036
# 3             Eleito  2022-10-31 00:28:52    BR  280001607829
# 4         Não Eleito  2022-10-31 00:28:52    BR  280001618036
# 5             Eleito  2022-10-31 00:28:52    BR  280001607829
# 6         Não Eleito  2022-10-31 00:28:52    BR  280001618036
# 7             Eleito  2022-10-31 00:28:52    BR  280001607829
#
#   nm_tipo_destinacao_votos  sq_eleicao_divulga pc_votos_validos  \
# 0                   Válido          2040602022           0,6359
# 1                   Válido          2040602022           0,3641
# 2                   Válido          2040602022            0,605
# 3                   Válido          2040602022            0,395
# 4                   Válido          2040602022           0,5939
# 5                   Válido          2040602022           0,4061
# 6                   Válido          2040602022           0,6518
# 7                   Válido          2040602022           0,3482
#
#    qt_votos_nom_validos  qt_votos_concorrentes
# 0                 69724                 109643
# 1                 39919                 109643
# 2                 38075                  62937
# 3                 24862                  62937
# 4                 65803                 110789
# 5                 44986                 110789
# 6                 94013                 144242
# 7                 50229                 144242

# %%
dados_agrupados = presidente2022.groupby(['nr_zona', 'nm_candidato'])['qt_votos_nom_validos'].sum().reset_index()

total_votos_validos = dados_agrupados['qt_votos_nom_validos'].sum()

plt.figure(figsize=(15, 10))
ax = sns.barplot(x='nr_zona', y='qt_votos_nom_validos', hue='nm_candidato', data=dados_agrupados, palette='viridis')

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

plt.xlabel('Zona Eleitoral')
plt.ylabel('Quantidade de Votos')
plt.title(f'Quantidade de Votos por Zona Eleitoral e Candidatos - Eleições 2022 - Total Votos Válidos {total_votos_validos}')
plt.legend(title='Candidatos', loc='upper left')
plt.show()
